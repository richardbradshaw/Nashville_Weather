# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from datetime import timedelta

# %%
forecast = pd.read_csv('forecastNash.csv', parse_dates=['endTime', 'startTime', 'retrievalDate'])
hourly_forecast = pd.read_csv('hourlyForecastNash.csv', parse_dates=['endTime', 'startTime', 'retrievalDate'])
observations = pd.read_csv('observedWeatherNash.csv', parse_dates=['retrievalDate', 'dateTime'])

# %%
forecast.head(20)
# Out:
#                                      detailedForecast             endTime  \
# 0   Areas of fog before 8am, then a slight chance ... 2021-06-05 18:00:00
# 1   A chance of showers and thunderstorms. Mostly ... 2021-06-06 06:00:00
# 2   Showers and thunderstorms likely. Mostly cloud... 2021-06-06 18:00:00
# 3   A chance of showers and thunderstorms. Mostly ... 2021-06-07 06:00:00
# 4   Showers and thunderstorms likely. Mostly cloud... 2021-06-07 18:00:00
# 5   Showers and thunderstorms likely. Mostly cloud... 2021-06-08 06:00:00
# 6   Showers and thunderstorms likely. Mostly cloud... 2021-06-08 18:00:00
# 7   Showers and thunderstorms likely. Mostly cloud... 2021-06-09 06:00:00
# 8   Showers and thunderstorms likely. Mostly cloud... 2021-06-09 18:00:00
# 9   Showers and thunderstorms likely. Mostly cloud... 2021-06-10 06:00:00
# 10  A chance of showers and thunderstorms. Partly ... 2021-06-10 18:00:00
# 11  A chance of showers and thunderstorms. Mostly ... 2021-06-11 06:00:00
# ...

# %%
# extract numerical rainfall amount forecast and assign them to low and high

rainList = ['tenth', 'quarter ', 'half', 'three', 'one', '1', '2']
rainValue = [0.1, 0.25, 0.5, 0.75, 1, 1, 2]

low = []
high = []

for text in forecast['detailedForecast']:
    if 'New rainfall amounts' in text:
        out = text.split('.')
        if 'less than' in text:
            high.append(0.0)
            low.append(0.1)
        elif 'between' in text:
            textSplit = out[-2].split('and')
            for i in range(len(rainList)):
                if rainList[i] in textSplit[0]:
                    low.append(rainValue[i])
                if rainList[i] in textSplit[1]:
                    high.append(rainValue[i])
    else:
        high.append(0.0)
        low.append(0.0)

# %%
# Add rainfall amount forecasts to columns in the forecast DataFrame

forecast['rain low'] = low
forecast['rain high'] = high

# %%
forecast['number'].value_counts()
# Out:
# 14    37
# 13    37
# 12    37
# 11    37
# 10    37
# 9     37
# 8     37
# 7     37
# 6     37
# 5     37
# 4     37
# 3     37
# 2     37
# 1     37
# Name: number, dtype: int64

# %%
number1 = forecast[forecast['number'] == 1]
number2 = forecast[forecast['number'] == 2]
number3 = forecast[forecast['number'] == 3]
number4 = forecast[forecast['number'] == 4]
number5 = forecast[forecast['number'] == 5]
number6 = forecast[forecast['number'] == 6]
number7 = forecast[forecast['number'] == 7]
number8 = forecast[forecast['number'] == 8]
number9 = forecast[forecast['number'] == 9]
number10 = forecast[forecast['number'] == 10]
number11 = forecast[forecast['number'] == 11]
number12 = forecast[forecast['number'] == 12]
number13 = forecast[forecast['number'] == 13]
number14 = forecast[forecast['number'] == 14]

# %%
plt.plot(number1['endTime'], number1['temperature'])

# %%
for num in forecast['number']:
    days = forecast['endTime'].iloc[num].date() - forecast['retrievalDate'].iloc[num].date()
#     print(num)
    print(days)
# Out:
# 1 day, 0:00:00
# 1 day, 0:00:00
# 2 days, 0:00:00
# 2 days, 0:00:00
# 3 days, 0:00:00
# 3 days, 0:00:00
# 4 days, 0:00:00
# 4 days, 0:00:00
# 5 days, 0:00:00
# 5 days, 0:00:00
# 6 days, 0:00:00
# 6 days, 0:00:00
# 7 days, 0:00:00
# 0:00:00
# 1 day, 0:00:00
# 1 day, 0:00:00
# 2 days, 0:00:00
# 2 days, 0:00:00
# 3 days, 0:00:00
# 3 days, 0:00:00
# 4 days, 0:00:00
# 4 days, 0:00:00
# 5 days, 0:00:00
# 5 days, 0:00:00
# 6 days, 0:00:00
# 6 days, 0:00:00
# 7 days, 0:00:00
# 0:00:00
# 1 day, 0:00:00
# 1 day, 0:00:00
# 2 days, 0:00:00
# 2 days, 0:00:00
# 3 days, 0:00:00
# 3 days, 0:00:00
# 4 days, 0:00:00
# 4 days, 0:00:00
# 5 days, 0:00:00
# 5 days, 0:00:00
# 6 days, 0:00:00
# 6 days, 0:00:00
# 7 days, 0:00:00
# 0:00:00
# 1 day, 0:00:00
# 1 day, 0:00:00
# 2 days, 0:00:00
# 2 days, 0:00:00
# 3 days, 0:00:00
# 3 days, 0:00:00
# 4 days, 0:00:00
# 4 days, 0:00:00
# 5 days, 0:00:00
# 5 days, 0:00:00
# 6 days, 0:00:00
# 6 days, 0:00:00
# 7 days, 0:00:00
# 0:00:00
# 1 day, 0:00:00
# ...

# %%
test = forecast['endTime'].iloc[0].date()
test
# Out:
# datetime.date(2021, 6, 5)

# %%
forecast['retrievalDate'].iloc[0].date()
# Out:
# datetime.date(2021, 6, 5)

# %%
test + timedelta(days=1)
# Out:
# datetime.date(2021, 6, 6)

# %%
number1.duplicated(subset=['endTime'])
# Out:
# 0      False
# 14     False
# 28     False
# 42     False
# 56     False
# 70     False
# 84     False
# 98     False
# 112    False
# 126     True
# 140     True
# 154    False
# 168    False
# 182     True
# 196    False
# 210    False
# 224    False
# 238    False
# 252    False
# 266    False
# 280    False
# 294    False
# 308    False
# 322    False
# 336    False
# 350    False
# 364    False
# 378    False
# 392    False
# 406    False
# 420    False
# 434    False
# 448    False
# 462    False
# 476    False
# 490     True
# 504    False
# dtype: bool

# %%
forecast[forecast['number'] == 1].iloc[0]
# Out:
# detailedForecast    Areas of fog before 8am, then a slight chance ...
# endTime                                           2021-06-05 18:00:00
# icon                https://api.weather.gov/icons/land/day/fog/tsr...
# isDaytime                                                        True
# name                                                            Today
# number                                                              1
# shortForecast       Areas Of Fog then Slight Chance Showers And Th...
# startTime                                         2021-06-05 06:00:00
# temperature                                                        87
# temperatureTrend                                                  NaN
# temperatureUnit                                                     F
# windDirection                                                       S
# windSpeed                                                  0 to 5 mph
# ...

# %%
dateOffsetDict = {1:0, 2:1, 3:1, 4:2, 5:2, 6:3, 7:3, 8:4, 9:4, 10:5, 11:5, 12:6, 13:6, 14:7}

# %%
for index, row in forecast.iterrows():
    val = dateOffsetDict[row['number']]
    if row['endTime'].date() != row['retrievalDate'].date() + timedelta(days=val):
#         print('yes')
        forecast.loc[index,'endTime'] = forecast.loc[index,'endTime'] + timedelta(days=val)
#     else:
#         forecast.loc[index,'endTime'] = row['endTime']

# %%
forecast.loc[126:127]
# Out:
#                                       detailedForecast             endTime  \
# 126  Sunny. High near 91, with temperatures falling... 2021-06-14 18:00:00
# 127  Mostly clear, with a low around 64. North nort... 2021-06-16 06:00:00
#
#                                                   icon  isDaytime     name  \
# 126  https://api.weather.gov/icons/land/day/few?siz...       True    Today
# 127  https://api.weather.gov/icons/land/night/few?s...      False  Tonight
#
#      number shortForecast           startTime  temperature temperatureTrend  \
# 126       1         Sunny 2021-06-14 06:00:00           91          falling
# 127       2  Mostly Clear 2021-06-14 18:00:00           64              NaN
#
#     temperatureUnit windDirection    windSpeed  precip%  windSpeedMin  \
# 126               F           NNW  5 to 10 mph        0             5
# 127               F           NNW  5 to 10 mph        0             5
#
#      windSpeedMax       retrievalDate  rain low  rain high
# ...

# %%
for index, row in forecast.iterrows():
    val = dateOffsetDict[row['number']]
#     print(val)
    print(row['endTime'].date() != row['retrievalDate'].date() + timedelta(days=val))
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
# endTime-2 = 
for i in range(len(forecast)):
    val = dateOffsetDict[forecast['number'].iloc[i]]
    if forecast['endTime'].iloc[i].date() != forecast['retrievalDate'].iloc[i].date() + timedelta(days=val):
        print('yes')
#         forecast['endTime-2'].iloc[i] = forecast['endTime'].iloc[i] + timedelta(days=val)
#     else: prin
#         forecast['endTime-2'].iloc[i] = forecast['endTime'].iloc[i]
# Out:
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes

# %%
test = forecast['endTime'].iloc[1] + timedelta(days=2)
test
# Out:
# Timestamp('2021-06-08 06:00:00')

# %%
for key, val in dateOffsetDict.items():
    temp = forecast[forecast['number'] == key]
    # check for duplicates
    tempDup = temp[temp.duplicated(subset=['endTime'])]
    for i in range(len(temp)):
        if temp['endTime'].iloc[i].date() != temp['retrievalDate'].iloc[i].date() + timedelta(days=val):
            print('yes')
#             temp['endTime'].iloc[i] = temp['endTime'].iloc[i].date() + timedelta(days=val)
#             print(temp['endTime'])
        else: print('no')
# Out:
# no
# no
# no
# no
# no
# no
# no
# no
# no
# yes
# yes
# no
# no
# yes
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# yes
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# yes
# no
# no
# yes
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# yes
# no
# no
# yes
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# yes
# no
# no
# no
# yes
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# yes
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# yes
# no
# no
# no
# yes
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# yes
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# yes
# yes
# ...
